// %%
%useLatestDescriptors
%use dataframe
%use kandy

// %%
val jvmData = DataFrame.read(fileOrUrl = "./java2023.csv", delimiter = ';')

// %%
import org.jetbrains.kotlinx.kandy.ir.Plot

fun createBarPlot(column: String, plotTitle: String): Plot {
    val myPlot = jvmData
        .filter { it.get(column) != null }
        .split{ it.get(column) }
        .by { it.toString().split(",").map { it.trim() } }
        .intoRows()
        .groupBy{it.get(column)}
        .aggregate { 
            count() into "Ocurrencias"
         }
         .sortBy("Ocurrencias")
         .plot { 
            barsH {
                y(column) { scale = categorical() }
                x("Ocurrencias")
                fillColor(column) { 
                    scale = categoricalColorHue()
        
                }
            }
            layout.title = plotTitle
            layout.size = 950 to 900
        }
    
    return myPlot
}

// %%
fun createFrequencyTable(column: String): DataFrame<_DataFrameType2>{
    val myData = jvmData
        .filter { it.get(column) != null }
        .split{ it.get(column) }
        .by { it.toString().split(",").map { it.trim() } }
        .intoRows()
        .groupBy{it.get(column)}
        .aggregate { 
            count() into "Ocurrencias"
         }
         .sortByDesc("Ocurrencias")
         
    return myData
}
// Out:
// Line_141.jupyter.kts (1:53 - 68) Unresolved reference: _DataFrameType2

// %% [markdown]
// # Generales
//
// * Total de participantes: 89
// * Fecha de apertura de encuesta: 2023-09-11
// * Fecha de cierre de encuesta: 2023-09-151
//
// Todas las preguntas abajo listadas a excepción de la edad aceptaban respuestas multiples (y pueden sumar más de 89), la encuesta se elaboró bajo la premisa de que muchos desarrolladores cuentan con más de un équipo, sistema operativo o máquina virtual de Java.

// %% [markdown]
// ## Estructura de datos

// %%
jvmData.head()
// Out:
//             <iframe onload="o_resize_iframe_out_10()" style="width:100%;" class="result_container" id="iframe_out_10" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//
// &lt;table class=&quot;dataframe&quot; id=&quot;df_-1610612727&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 5, columnsCount = 18&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let left = leftBorder
//             let right = rightBorder
//             if (size &gt; 1) {

// %%
jvmData.schema()
// Out:
// Timestamp: String
// Experiencia: Int?
// JDK_dev: String?
// JDKs_prod: String?
// Versiones: String?
// IDEs: String
// Uso: String
// JVM_langs: String
// Other_langs: String?
// Servers: String?
// Microservice_frameworks: String?
// Containers: String?
// FaaS: String?
// OS_dev: String
// OS_Prod: String?
// Rol: String?
// Jconf: String?
// Correo: String?

// %% [markdown]
// # Experiencia
//
// Al igual que en otras ocasiones se marca una tendencia clara, **la comunidad Java de Guatemala es una comunidad relativamente joven**, vemos que existe una alta concentración en personas que tienen menos de 10 años utilizando Java a pesar de que Java tiene más de 25 años

// %%
jvmData
        .filter { Experiencia != null }
        .groupBy { Experiencia }
        .aggregate { 
            count() into "Ocurrencias"
         }
         .sortByDesc("Ocurrencias")
// Out:
//             <iframe onload="o_resize_iframe_out_11()" style="width:100%;" class="result_container" id="iframe_out_11" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//
// &lt;table class=&quot;dataframe&quot; id=&quot;df_-1610612726&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 19, columnsCount = 2&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let left = leftBorder
//             let right = rightBorder
//             if (size &gt; 1) {

// %%
jvmData
        .filter { Experiencia != null }
        .groupBy { Experiencia }
        .aggregate { 
            count() into "Ocurrencias"
         }
        .plot { 
            bars { 
                x(Experiencia)
                y("Ocurrencias")
                fillColor(Experiencia) { 
                    scale = categoricalColorHue()
                }
            }
            
            layout {
                title = "Desarrolladores por edad"
                size = 900 to 550
            }
        }
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="6OB5Uj"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Desarrolladores por edad"
// },
// "mapping":{
// },
// "data":{
// "Ocurrencias":[8.0,7.0,5.0,7.0,2.0,9.0,5.0,7.0,8.0,4.0,2.0,1.0,1.0,1.0,8.0,1.0,3.0,1.0,1.0],
// "Experiencia":[10.0,12.0,2.0,3.0,7.0,5.0,15.0,4.0,6.0,1.0,20.0,9.0,13.0,11.0,8.0,16.0,18.0,14.0,19.0]
// },
// "ggsize":{
// "width":900.0,
// "height":550.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[null,null]
// },{
// "aesthetic":"y",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "x":"Experiencia",
// "y":"Ocurrencias",
// "fill":"Experiencia"
// },
// "stat":"identity",
// "sampling":"none",
// "position":"dodge",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("6OB5Uj");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=8d3ee101-3e20-4540-b081-06106ba3de5e xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="900.0" height="550.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pm96qtn .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pm96qtn .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pm96qtn .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pm96qtn .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pm96qtn .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pm96qtn .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pm96qtn .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dTAWJJS .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pm96qtn .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pm96qtn .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dTAWJJS .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pm96qtn .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pm96qtn .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dTAWJJS .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dTAWJJS .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dTAWJJS .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pm96qtn">
//     <rect x="0.0" y="0.0" height="550.0" width="900.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(13.980605455468202 470.0 ) ">
//         <line x1="15.035999187498518" y1="-0.0" x2="15.035999187498518" y2="-470.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="82.61352362569411" y1="-0.0" x2="82.61352362569411" y2="-470.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="150.1910480638897" y1="-0.0" x2="150.1910480638897" y2="-470.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="217.7685725020853" y1="-0.0" x2="217.7685725020853" y2="-470.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="285.3460969402809" y1="-0.0" x2="285.3460969402809" y2="-470.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="352.9236213784765" y1="-0.0" x2="352.9236213784765" y2="-470.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="420.5011458166721" y1="-0.0" x2="420.5011458166721" y2="-470.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="488.0786702548677" y1="-0.0" x2="488.0786702548677" y2="-470.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="555.6561946930633" y1="-0.0" x2="555.6561946930633" y2="-470.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="623.2337191312589" y1="-0.0" x2="623.2337191312589" y2="-470.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="690.8112435694545" y1="-0.0" x2="690.8112435694545" y2="-470.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(15.035999187498518 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>
//           </g>
//         </g>
//         <g transform="translate(82.61352362569411 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             2
//             </text>
//           </g>
//         </g>
//         <g transform="translate(150.1910480638897 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             4
//             </text>
//           </g>
//         </g>
//         <g transform="translate(217.7685725020853 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             6
//             </text>
//           </g>
//         </g>
//         <g transform="translate(285.3460969402809 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             8

// %% [markdown]
// # JVM Desarrollo
//
// El termino Java suele estar relacionado con Oracle, por lo que no es de extrañar que OracleJDK (HotSpot) sea la distribución más utilizada para programar en estaciones de trabajo.

// %%
jvmData
.filter { JDK_dev != null }
.split { JDK_dev }.by { it.split(",").map { it.trim() } }.intoRows()
.sortBy{ JDK_dev }
.groupBy { JDK_dev }
.aggregate { 
            count() into "Ocurrencias"
         }
// Out:
//             <iframe onload="o_resize_iframe_out_12()" style="width:100%;" class="result_container" id="iframe_out_12" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//
// &lt;table class=&quot;dataframe&quot; id=&quot;df_-1610612725&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 10, columnsCount = 2&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let left = leftBorder
//             let right = rightBorder
//             if (size &gt; 1) {

// %%
createBarPlot("JDK_dev", "JDK más utilizada en desarrollo")
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="bvPPnl"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"JDK más utilizada en desarrollo"
// },
// "mapping":{
// },
// "data":{
// "Ocurrencias":[2.0,5.0,6.0,8.0,10.0,11.0,13.0,21.0,39.0,48.0],
// "JDK_dev":["IBM Semeru/Open J9","Microsoft build of OpenJDK","Red Hat OpenJDK","Oracle GraalVM","Amazon Corretto","Liberica JDK","Azul Zulu/Zing","Eclipse Temurin/AdoptOpenJDK","OpenJDK en mi distribución Linux","Oracle JDK"]
// },
// "ggsize":{
// "width":950.0,
// "height":900.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "discrete":true
// },{
// "aesthetic":"x",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "y":"JDK_dev",
// "x":"Ocurrencias",
// "fill":"JDK_dev"
// },
// "stat":"identity",
// "orientation":"y",
// "sampling":"none",
// "position":"identity",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("bvPPnl");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=83b1a5fd-1fcc-4f30-96f2-ee7fa1465c26 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="900.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #ps5xADZ .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps5xADZ .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps5xADZ .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps5xADZ .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps5xADZ .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps5xADZ .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps5xADZ .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d1I9nkI .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps5xADZ .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps5xADZ .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d1I9nkI .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps5xADZ .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps5xADZ .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d1I9nkI .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d1I9nkI .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #d1I9nkI .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="ps5xADZ">
//     <rect x="0.0" y="0.0" height="900.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(238.51557127438616 820.0 ) ">
//         <line x1="79.16241165148683" y1="-0.0" x2="79.16241165148683" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="158.32482330297367" y1="-0.0" x2="158.32482330297367" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="237.48723495446052" y1="-0.0" x2="237.48723495446052" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="316.64964660594734" y1="-0.0" x2="316.64964660594734" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>
//           </g>
//         </g>
//         <g transform="translate(79.16241165148683 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             10
//             </text>
//           </g>
//         </g>
//         <g transform="translate(158.32482330297367 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             20
//             </text>
//           </g>
//         </g>
//         <g transform="translate(237.48723495446052 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             30
//             </text>
//           </g>
//         </g>
//         <g transform="translate(316.64964660594734 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             40
//             </text>
//           </g>
//         </g>
//         <g transform="translate(395.81205825743416 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             50
//             </text>
//           </g>
//         </g>
//         <line x1="0.0" y1="0.0" x2="398.97855472349363" y2="0.0" stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0">
//         </line>
//       </g>
//       <g transform="translate(238.51557127438616 0.0 ) ">
//         <line x1="0.0" y1="768.252427184466" x2="398.97855472349363" y2="768.252427184466" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="688.6407766990291" x2="398.97855472349363" y2="688.6407766990291" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="609.0291262135922" x2="398.97855472349363" y2="609.029126213592

// %% [markdown]
// # JVM Producción
//
// Con el cambio de licencia de Oracle para producción y por primera vez en nuestra encuesta, se observa que las personas tienden a dar preferencia a OpenJDK en sus ambientes de producción. Aunque HotSpot está en segundo lugar.

// %%
createBarPlot("JDKs_prod", "JDK más utilizada en producción")
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="eWJF3V"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"JDK más utilizada en producción"
// },
// "mapping":{
// },
// "data":{
// "Ocurrencias":[2.0,2.0,3.0,4.0,6.0,12.0,15.0,15.0,33.0,36.0],
// "JDKs_prod":["Oracle GraalVM","IBM Semeru/Open J9","Red Hat OpenJDK","LibericaJDK","Microsoft build of OpenJDK","Azul Zulu/Zing","Amazon Corretto","Eclipse Temurin/AdoptOpenJDK","Oracle JDK","OpenJDK en mi distribución Linux"]
// },
// "ggsize":{
// "width":950.0,
// "height":900.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "discrete":true
// },{
// "aesthetic":"x",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "y":"JDKs_prod",
// "x":"Ocurrencias",
// "fill":"JDKs_prod"
// },
// "stat":"identity",
// "orientation":"y",
// "sampling":"none",
// "position":"identity",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("eWJF3V");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=9012664c-3807-4391-ab0a-e0087b754d68 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="900.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #p46eXX0 .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46eXX0 .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46eXX0 .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46eXX0 .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46eXX0 .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46eXX0 .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46eXX0 .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dSeayzW .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46eXX0 .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46eXX0 .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dSeayzW .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46eXX0 .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46eXX0 .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dSeayzW .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dSeayzW .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dSeayzW .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="p46eXX0">
//     <rect x="0.0" y="0.0" height="900.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(238.51557127438616 820.0 ) ">
//         <line x1="105.54988220198246" y1="-0.0" x2="105.54988220198246" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="211.0997644039649" y1="-0.0" x2="211.0997644039649" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="316.64964660594734" y1="-0.0" x2="316.64964660594734" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>
//           </g>
//         </g>
//         <g transform="translate(105.54988220198246 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             10
//             </text>
//           </g>
//         </g>
//         <g transform="translate(211.0997644039649 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             20
//             </text>
//           </g>
//         </g>
//         <g transform="translate(316.64964660594734 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             30
//             </text>
//           </g>
//         </g>
//         <line x1="0.0" y1="0.0" x2="398.97855472349363" y2="0.0" stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0">
//         </line>
//       </g>
//       <g transform="translate(238.51557127438616 0.0 ) ">
//         <line x1="0.0" y1="768.252427184466" x2="398.97855472349363" y2="768.252427184466" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="688.6407766990291" x2="398.97855472349363" y2="688.6407766990291" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="609.0291262135922" x2="398.97855472349363" y2="609.0291262135922" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="529.4174757281553" x2="398.97855472349363" y2="529.4174757281553" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="449.8058252427184" x2="398.97855472349363" y2="449.8058252427184" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="370.19417475728153" x2="398.97855472349363" y2="370.19417475728153" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="290.5825242718446" x2="398.97855472349363" y2="290.5825242718446" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="210.97087378640776" x2="398.97855472349363" y2="210.970873

// %% [markdown]
// # Versiones Java
//
// Java 8 finalmente dejó de ser la versión de Java más utilizada. Vemos también alta presencia de versiones LTS.

// %%
createBarPlot("Versiones", "Versiones de Java más utilizadas")
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="Fbw6yP"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Versiones de Java más utilizadas"
// },
// "mapping":{
// },
// "data":{
// "Ocurrencias":[1.0,1.0,1.0,2.0,6.0,45.0,46.0,52.0],
// "Versiones":["6","20","Java 19","Java 21","Java 7 o anterior","Java 17","Java 8","Java 11"]
// },
// "ggsize":{
// "width":950.0,
// "height":900.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "discrete":true
// },{
// "aesthetic":"x",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "y":"Versiones",
// "x":"Ocurrencias",
// "fill":"Versiones"
// },
// "stat":"identity",
// "orientation":"y",
// "sampling":"none",
// "position":"identity",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("Fbw6yP");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=e05be79b-be5b-4291-ad60-bfa8a93f6c94 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="900.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #p0KO5Oh .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p0KO5Oh .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p0KO5Oh .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p0KO5Oh .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p0KO5Oh .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p0KO5Oh .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p0KO5Oh .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dWIelr3 .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p0KO5Oh .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p0KO5Oh .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dWIelr3 .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p0KO5Oh .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p0KO5Oh .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dWIelr3 .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dWIelr3 .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dWIelr3 .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="p0KO5Oh">
//     <rect x="0.0" y="0.0" height="900.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(118.41337157397388 820.0 ) ">
//         <line x1="58.53323755717199" y1="-0.0" x2="58.53323755717199" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="117.06647511434397" y1="-0.0" x2="117.06647511434397" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="175.59971267151596" y1="-0.0" x2="175.59971267151596" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="234.13295022868795" y1="-0.0" x2="234.13295022868795" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="292.66618778585996" y1="-0.0" x2="292.66618778585996" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="351.1994253430319" y1="-0.0" x2="351.1994253430319" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="409.7326629002039" y1="-0.0" x2="409.7326629002039" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="468.2659004573759" y1="-0.0" x2="468.2659004573759" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="526.7991380145479" y1="-0.0" x2="526.7991380145479" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="585.3323755717199" y1="-0.0" x2="585.3323755717199" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>
//           </g>
//         </g>
//         <g transform="translate(58.53323755717199 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             5
//             </text>
//           </g>
//         </g>
//         <g transform="translate(117.06647511434397 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             10
//             </text>
//           </g>
//         </g>
//         <g transform="translate(175.59971267151596 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             15
//             </text>
//           </g>
//         </g>
//         <g transform="translate(234.13295022868795 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             20
//             </text>
//           </g>
//         </g>
//         <g transform="translate(292.66618778585996 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">

// %%
createFrequencyTable("Versiones")
// Out:
// Line_150.jupyter.kts (1:1 - 21) Unresolved reference: createFrequencyTable

// %% [markdown]
// # IDEs
//
// Diferente de otros años, IntelliJ y VS Code han tomado el lugar que en su momento tuvieron NetBeans y Eclipse en nuestra comunidad. Larga vida a NetBeans y Eclipse.

// %%
createBarPlot("IDEs", "Uso de IDEs")
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="q3as4O"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Uso de IDEs"
// },
// "mapping":{
// },
// "data":{
// "Ocurrencias":[1.0,1.0,10.0,23.0,37.0,38.0,54.0],
// "IDEs":["Vim","sts","Android Studio","Eclipse IDE","Apache NetBeans","VS Code","IntelliJ IDEA"]
// },
// "ggsize":{
// "width":950.0,
// "height":900.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "discrete":true
// },{
// "aesthetic":"x",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "y":"IDEs",
// "x":"Ocurrencias",
// "fill":"IDEs"
// },
// "stat":"identity",
// "orientation":"y",
// "sampling":"none",
// "position":"identity",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("q3as4O");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=185f93b0-1666-40ac-afdd-87c19f197071 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="900.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pCBhKCg .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pCBhKCg .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pCBhKCg .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pCBhKCg .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pCBhKCg .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pCBhKCg .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pCBhKCg .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dd8S3eq .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pCBhKCg .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pCBhKCg .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dd8S3eq .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pCBhKCg .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pCBhKCg .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dd8S3eq .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dd8S3eq .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dd8S3eq .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pCBhKCg">
//     <rect x="0.0" y="0.0" height="900.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(125.49572070248537 820.0 ) ">
//         <line x1="55.116248312812615" y1="-0.0" x2="55.116248312812615" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="110.23249662562523" y1="-0.0" x2="110.23249662562523" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="165.34874493843785" y1="-0.0" x2="165.34874493843785" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="220.46499325125046" y1="-0.0" x2="220.46499325125046" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="275.5812415640631" y1="-0.0" x2="275.5812415640631" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="330.6974898768757" y1="-0.0" x2="330.6974898768757" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="385.8137381896883" y1="-0.0" x2="385.8137381896883" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="440.9299865025009" y1="-0.0" x2="440.9299865025009" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="496.0462348153136" y1="-0.0" x2="496.0462348153136" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="551.1624831281262" y1="-0.0" x2="551.1624831281262" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="606.2787314409388" y1="-0.0" x2="606.2787314409388" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>
//           </g>
//         </g>
//         <g transform="translate(55.116248312812615 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             5
//             </text>
//           </g>
//         </g>
//         <g transform="translate(110.23249662562523 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             10
//             </text>
//           </g>
//         </g>
//         <g transform="translate(165.34874493843785 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             15
//             </text>
//           </g>
//         </g>
//         <g transform="translate(220.46499325125046 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             20
//             </text>
//           </g>
//         </g>
//         <g transform="t

// %%
createFrequencyTable("IDEs")
// Out:
// Line_152.jupyter.kts (1:1 - 21) Unresolved reference: createFrequencyTable

// %% [markdown]
// # Tipos de desarrollo
//
// Como es de suponerse, el terreno donde más vemos Java es en el backend.

// %%
createBarPlot("Uso", "Tipos de desarrollo")
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="1NBG1I"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Tipos de desarrollo"
// },
// "mapping":{
// },
// "data":{
// "Uso":["IoT","Ingenieria de datos","Movíl","Frontend","Escritorio","Backend"],
// "Ocurrencias":[1.0,5.0,12.0,16.0,18.0,83.0]
// },
// "ggsize":{
// "width":950.0,
// "height":900.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "discrete":true
// },{
// "aesthetic":"x",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "y":"Uso",
// "x":"Ocurrencias",
// "fill":"Uso"
// },
// "stat":"identity",
// "orientation":"y",
// "sampling":"none",
// "position":"identity",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("1NBG1I");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=2ec3590c-4c2b-4656-afb6-74332b8f5f68 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="900.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pvO4trX .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvO4trX .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvO4trX .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvO4trX .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvO4trX .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvO4trX .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvO4trX .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dHez0Dq .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvO4trX .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvO4trX .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dHez0Dq .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvO4trX .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvO4trX .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dHez0Dq .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dHez0Dq .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dHez0Dq .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pvO4trX">
//     <rect x="0.0" y="0.0" height="900.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(137.28169763103347 820.0 ) ">
//         <line x1="69.012771314997" y1="-0.0" x2="69.012771314997" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="138.025542629994" y1="-0.0" x2="138.025542629994" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="207.03831394499102" y1="-0.0" x2="207.03831394499102" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="276.051085259988" y1="-0.0" x2="276.051085259988" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="345.06385657498504" y1="-0.0" x2="345.06385657498504" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="414.07662788998203" y1="-0.0" x2="414.07662788998203" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="483.08939920497903" y1="-0.0" x2="483.08939920497903" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="552.102170519976" y1="-0.0" x2="552.102170519976" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>
//           </g>
//         </g>
//         <g transform="translate(69.012771314997 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             10
//             </text>
//           </g>
//         </g>
//         <g transform="translate(138.025542629994 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             20
//             </text>
//           </g>
//         </g>
//         <g transform="translate(207.03831394499102 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             30
//             </text>
//           </g>
//         </g>
//         <g transform="translate(276.051085259988 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             40
//             </text>
//           </g>
//         </g>
//         <g transform="translate(345.06385657498504 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             50
//             </text>
//           </g>
//         </g>
//         <g transform="translate(414.07662788998203 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g trans

// %%
createFrequencyTable("Uso")
// Out:
// Line_154.jupyter.kts (1:1 - 21) Unresolved reference: createFrequencyTable

// %% [markdown]
// # Lenguajes de la JVM
//
// Se observa alta presencia de Kotlin como segundo lenguaje de la JVM y aunque era una opción en la encuesta, al parecer Clojure no es popular por estas latitudes.

// %%
createBarPlot("JVM_langs", "Lenguajes JVM")
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="AHBNz8"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Lenguajes JVM"
// },
// "mapping":{
// },
// "data":{
// "Ocurrencias":[2.0,9.0,9.0,21.0,89.0],
// "JVM_langs":["Scala","Groovy","JavaScript (GraalVM/Rhino/Nashorn)","Kotlin","Java"]
// },
// "ggsize":{
// "width":950.0,
// "height":900.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "discrete":true
// },{
// "aesthetic":"x",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "y":"JVM_langs",
// "x":"Ocurrencias",
// "fill":"JVM_langs"
// },
// "stat":"identity",
// "orientation":"y",
// "sampling":"none",
// "position":"identity",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("AHBNz8");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=2dd3dee5-1e6a-41e0-967e-62cff7a35f7b xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="900.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pUhKA3W .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pUhKA3W .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pUhKA3W .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pUhKA3W .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pUhKA3W .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pUhKA3W .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pUhKA3W .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dJIZD58 .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pUhKA3W .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pUhKA3W .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dJIZD58 .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pUhKA3W .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pUhKA3W .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dJIZD58 .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dJIZD58 .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dJIZD58 .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pUhKA3W">
//     <rect x="0.0" y="0.0" height="900.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(259.5998924723838 820.0 ) ">
//         <line x1="76.36381216211844" y1="-0.0" x2="76.36381216211844" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="152.72762432423687" y1="-0.0" x2="152.72762432423687" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="229.09143648635532" y1="-0.0" x2="229.09143648635532" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="305.45524864847374" y1="-0.0" x2="305.45524864847374" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>
//           </g>
//         </g>
//         <g transform="translate(76.36381216211844 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             20
//             </text>
//           </g>
//         </g>
//         <g transform="translate(152.72762432423687 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             40
//             </text>
//           </g>
//         </g>
//         <g transform="translate(229.09143648635532 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             60
//             </text>
//           </g>
//         </g>
//         <g transform="translate(305.45524864847374 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             80
//             </text>
//           </g>
//         </g>
//         <line x1="0.0" y1="0.0" x2="356.8099123274984" y2="0.0" stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0">
//         </line>
//       </g>
//       <g transform="translate(259.5998924723838 0.0 ) ">
//         <line x1="0.0" y1="719.433962264151" x2="356.8099123274984" y2="719.433962264151" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="564.7169811320755" x2="356.8099123274984" y2="564.7169811320755" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="410.00000000000006" x2="356.8099123274984" y2="410.00000000000006" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="255.28301886792462" x2="356.8099123274984" y2="255.28301886792462" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="100.56603773584914" x2="356.8099123274984" y2="100.56603773584914" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 719.433962264151 ) ">
//           <g transform="translate(-3.0 0.0

// %%
createFrequencyTable("JVM_langs")
// Out:
// Line_156.jupyter.kts (1:1 - 21) Unresolved reference: createFrequencyTable

// %% [markdown]
// # Otros lenguajes no JVM
//
// Dado que Java es un lenguaje backend, al parecer el segundo gran lenguaje que los desarrolladores utilizan es SQL. Aunque se observa buena presencia de JS y Python

// %%
createBarPlot("Other_langs", "Tipos de desarrollo")
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="supDTV"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Tipos de desarrollo"
// },
// "mapping":{
// },
// "data":{
// "Ocurrencias":[1.0,1.0,1.0,2.0,4.0,11.0,43.0,61.0,73.0],
// "Other_langs":["React","Rust","PHP","C#","Ruby","Go","Python","JavaScript (Deno/NodeJS)","SQL"]
// },
// "ggsize":{
// "width":950.0,
// "height":900.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "discrete":true
// },{
// "aesthetic":"x",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "y":"Other_langs",
// "x":"Ocurrencias",
// "fill":"Other_langs"
// },
// "stat":"identity",
// "orientation":"y",
// "sampling":"none",
// "position":"identity",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("supDTV");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=40c2d3c3-c438-4bd6-bef2-27287ad01aec xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="900.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #p46Pont .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46Pont .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46Pont .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46Pont .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46Pont .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46Pont .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46Pont .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d3RaGQ2 .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46Pont .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46Pont .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d3RaGQ2 .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46Pont .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p46Pont .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d3RaGQ2 .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d3RaGQ2 .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #d3RaGQ2 .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="p46Pont">
//     <rect x="0.0" y="0.0" height="900.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(183.2633529467308 820.0 ) ">
//         <line x1="66.46875295222495" y1="-0.0" x2="66.46875295222495" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="132.9375059044499" y1="-0.0" x2="132.9375059044499" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="199.40625885667484" y1="-0.0" x2="199.40625885667484" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="265.8750118088998" y1="-0.0" x2="265.8750118088998" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="332.34376476112476" y1="-0.0" x2="332.34376476112476" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="398.8125177133497" y1="-0.0" x2="398.8125177133497" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="465.28127066557465" y1="-0.0" x2="465.28127066557465" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>
//           </g>
//         </g>
//         <g transform="translate(66.46875295222495 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             10
//             </text>
//           </g>
//         </g>
//         <g transform="translate(132.9375059044499 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             20
//             </text>
//           </g>
//         </g>
//         <g transform="translate(199.40625885667484 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             30
//             </text>
//           </g>
//         </g>
//         <g transform="translate(265.8750118088998 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             40
//             </text>
//           </g>
//         </g>
//         <g transform="translate(332.34376476112476 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             50
//             </text>
//           </g>
//         </g>
//         <g transform="translate(398.8125177133497 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">

// %%
createFrequencyTable("Other_langs")
// Out:
// Line_158.jupyter.kts (1:1 - 21) Unresolved reference: createFrequencyTable

// %% [markdown]
// # Uso de servidores de aplicaciones
//
// Tomcat sigue como el rey de servidores de aplicaciones tradicionales y se observa que Payara tomá una segunda posición en la preferencia Guatemalteca.

// %%
createBarPlot("Servers", "Servidores de aplicaciones")
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="vtb2Vx"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Servidores de aplicaciones"
// },
// "mapping":{
// },
// "data":{
// "Ocurrencias":[1.0,2.0,4.0,4.0,9.0,11.0,20.0,26.0,70.0],
// "Servers":["Glassfish","Eclipse Jetty","IBM Websphere (Websphere Liberty)","Red Hat JBoss","Red Hat Wildfly","Oracle WebLogic","Apache TomEE","Payara","Apache Tomcat"]
// },
// "ggsize":{
// "width":950.0,
// "height":900.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "discrete":true
// },{
// "aesthetic":"x",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "y":"Servers",
// "x":"Ocurrencias",
// "fill":"Servers"
// },
// "stat":"identity",
// "orientation":"y",
// "sampling":"none",
// "position":"identity",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("vtb2Vx");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=ecff618e-e5ea-417d-8a57-2c8b7c99fc22 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="900.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pFWqU3l .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pFWqU3l .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pFWqU3l .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pFWqU3l .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pFWqU3l .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pFWqU3l .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pFWqU3l .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dJGrHGo .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pFWqU3l .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pFWqU3l .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dJGrHGo .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pFWqU3l .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pFWqU3l .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dJGrHGo .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dJGrHGo .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dJGrHGo .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pFWqU3l">
//     <rect x="0.0" y="0.0" height="900.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(254.34227456289622 820.0 ) ">
//         <line x1="99.95242126434653" y1="-0.0" x2="99.95242126434653" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="199.90484252869305" y1="-0.0" x2="199.90484252869305" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="299.8572637930396" y1="-0.0" x2="299.8572637930396" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>
//           </g>
//         </g>
//         <g transform="translate(99.95242126434653 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             20
//             </text>
//           </g>
//         </g>
//         <g transform="translate(199.90484252869305 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             40
//             </text>
//           </g>
//         </g>
//         <g transform="translate(299.8572637930396 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             60
//             </text>
//           </g>
//         </g>
//         <line x1="0.0" y1="0.0" x2="367.32514814647345" y2="0.0" stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0">
//         </line>
//       </g>
//       <g transform="translate(254.34227456289622 0.0 ) ">
//         <line x1="0.0" y1="762.6881720430107" x2="367.32514814647345" y2="762.6881720430107" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="674.516129032258" x2="367.32514814647345" y2="674.516129032258" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="586.3440860215053" x2="367.32514814647345" y2="586.3440860215053" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="498.1720430107526" x2="367.32514814647345" y2="498.1720430107526" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="409.9999999999999" x2="367.32514814647345" y2="409.9999999999999" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="321.8279569892472" x2="367.32514814647345" y2="321.8279569892472" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="233.65591397849448" x2="367.32514814647345" y2="233.65591397849448" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="145.48387096774184" x2="367.32514814647345" y2="145.48387096774184" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">

// %%
createFrequencyTable("Servers")
// Out:
// Line_160.jupyter.kts (1:1 - 21) Unresolved reference: createFrequencyTable

// %% [markdown]
// # Frameworks de microservicios
//
// Aunque era algo bastante predecible, Spring Boot es el framework #1 para creación de microservicios. Aunque Quarkus de reciente aparición empieza a dar pelea.

// %%
createBarPlot("Microservice_frameworks", "Frameworks de microservicios")
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="KjnA9i"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Frameworks de microservicios"
// },
// "mapping":{
// },
// "data":{
// "Ocurrencias":[1.0,1.0,3.0,11.0,71.0],
// "Microservice_frameworks":["Dropwizard","Quarkus","Oracle Helidon","Red Hat Quarkus","Spring Boot"]
// },
// "ggsize":{
// "width":950.0,
// "height":900.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "discrete":true
// },{
// "aesthetic":"x",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "y":"Microservice_frameworks",
// "x":"Ocurrencias",
// "fill":"Microservice_frameworks"
// },
// "stat":"identity",
// "orientation":"y",
// "sampling":"none",
// "position":"identity",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("KjnA9i");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=99300784-dd27-475a-96ff-7077d7e9f5f6 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="900.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pEM747P .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEM747P .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEM747P .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEM747P .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEM747P .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEM747P .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEM747P .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dFNCSX7 .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEM747P .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEM747P .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dFNCSX7 .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEM747P .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEM747P .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dFNCSX7 .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dFNCSX7 .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dFNCSX7 .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pEM747P">
//     <rect x="0.0" y="0.0" height="900.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(121.1994080444402 820.0 ) ">
//         <line x1="77.2329007135015" y1="-0.0" x2="77.2329007135015" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="154.465801427003" y1="-0.0" x2="154.465801427003" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="231.69870214050448" y1="-0.0" x2="231.69870214050448" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="308.931602854006" y1="-0.0" x2="308.931602854006" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="386.1645035675075" y1="-0.0" x2="386.1645035675075" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="463.39740428100896" y1="-0.0" x2="463.39740428100896" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="540.6303049945104" y1="-0.0" x2="540.6303049945104" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>
//           </g>
//         </g>
//         <g transform="translate(77.2329007135015 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             10
//             </text>
//           </g>
//         </g>
//         <g transform="translate(154.465801427003 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             20
//             </text>
//           </g>
//         </g>
//         <g transform="translate(231.69870214050448 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             30
//             </text>
//           </g>
//         </g>
//         <g transform="translate(308.931602854006 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             40
//             </text>
//           </g>
//         </g>
//         <g transform="translate(386.1645035675075 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             50
//             </text>
//           </g>
//         </g>
//         <g transform="translate(463.39740428100896 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">

// %%
createFrequencyTable("Microservice_frameworks")
// Out:
// Line_162.jupyter.kts (1:1 - 21) Unresolved reference: createFrequencyTable

// %% [markdown]
// # Despliegue en contenedores
//
// En relación a las respuestas globales, casi la mitad no utiliza contenedores. Entre las opciones, Docker aun sigue siendo más popular que Kubernetes y alguien utiliza Nomad para despliegues.

// %%
createBarPlot("Containers", "Despliegue en contenedores")
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="GEMAcA"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Despliegue en contenedores"
// },
// "mapping":{
// },
// "data":{
// "Ocurrencias":[1.0,17.0,34.0,39.0],
// "Containers":["Hashicorp Nomad","Docker Swarm","Docker/Podman exclusivamente","Kubernetes"]
// },
// "ggsize":{
// "width":950.0,
// "height":900.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "discrete":true
// },{
// "aesthetic":"x",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "y":"Containers",
// "x":"Ocurrencias",
// "fill":"Containers"
// },
// "stat":"identity",
// "orientation":"y",
// "sampling":"none",
// "position":"identity",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("GEMAcA");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=1a95aa68-5a7f-4065-bcea-fe72297d501b xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="900.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pjCfBis .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjCfBis .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjCfBis .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjCfBis .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjCfBis .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjCfBis .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjCfBis .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dqLZtwh .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjCfBis .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjCfBis .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dqLZtwh .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjCfBis .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjCfBis .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dqLZtwh .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dqLZtwh .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dqLZtwh .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pjCfBis">
//     <rect x="0.0" y="0.0" height="900.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(226.9429554753757 820.0 ) ">
//         <line x1="103.08273170244554" y1="-0.0" x2="103.08273170244554" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="206.16546340489109" y1="-0.0" x2="206.16546340489109" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="309.24819510733664" y1="-0.0" x2="309.24819510733664" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="412.33092680978217" y1="-0.0" x2="412.33092680978217" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>
//           </g>
//         </g>
//         <g transform="translate(103.08273170244554 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             10
//             </text>
//           </g>
//         </g>
//         <g transform="translate(206.16546340489109 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             20
//             </text>
//           </g>
//         </g>
//         <g transform="translate(309.24819510733664 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             30
//             </text>
//           </g>
//         </g>
//         <g transform="translate(412.33092680978217 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             40
//             </text>
//           </g>
//         </g>
//         <line x1="0.0" y1="0.0" x2="422.12378632151456" y2="0.0" stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0">
//         </line>
//       </g>
//       <g transform="translate(226.9429554753757 0.0 ) ">
//         <line x1="0.0" y1="696.046511627907" x2="422.12378632151456" y2="696.046511627907" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="505.34883720930236" x2="422.12378632151456" y2="505.34883720930236" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="314.65116279069775" x2="422.12378632151456" y2="314.65116279069775" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="123.95348837209315" x2="422.12378632151456" y2="123.95348837209315" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 696.046511627907 ) ">
//           <g transform="translate(-3.0 0.0 ) ">
//             <text class="axis-text-y" text-anchor="end" dy="0.35em">
//             Hashicorp Nomad
//             </text>
//           </g>
//         </

// %%
createFrequencyTable("Containers")
// Out:
// Line_164.jupyter.kts (1:1 - 21) Unresolved reference: createFrequencyTable

// %% [markdown]
// # Despliegue en FaaS/Serverless
//
// AWS Lambda se coloca como el rey de Serverless con Java aunque en relación al total de respuestas, nuevamente casi la mitad de desarrolladores no utiliza modelos serverless para despliegues.

// %%
createBarPlot("FaaS", "Despliegue FaaS")
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="53caIl"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Despliegue FaaS"
// },
// "mapping":{
// },
// "data":{
// "Ocurrencias":[1.0,1.0,5.0,7.0,33.0],
// "FaaS":["Google Cloud Functions","Open FaaS","Oracle Functions","Azure Functions","AWS Lambda"]
// },
// "ggsize":{
// "width":950.0,
// "height":900.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "discrete":true
// },{
// "aesthetic":"x",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "y":"FaaS",
// "x":"Ocurrencias",
// "fill":"FaaS"
// },
// "stat":"identity",
// "orientation":"y",
// "sampling":"none",
// "position":"identity",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("53caIl");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=4fc20f8d-2229-4111-9960-0a368522c81f xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="900.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #poagBHs .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #poagBHs .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #poagBHs .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #poagBHs .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #poagBHs .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #poagBHs .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #poagBHs .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dog1Esv .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #poagBHs .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #poagBHs .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dog1Esv .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #poagBHs .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #poagBHs .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dog1Esv .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dog1Esv .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dog1Esv .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="poagBHs">
//     <rect x="0.0" y="0.0" height="900.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(169.38245955290165 820.0 ) ">
//         <line x1="77.52449901391958" y1="-0.0" x2="77.52449901391958" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="155.04899802783916" y1="-0.0" x2="155.04899802783916" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="232.57349704175874" y1="-0.0" x2="232.57349704175874" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="310.0979960556783" y1="-0.0" x2="310.0979960556783" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="387.6224950695979" y1="-0.0" x2="387.6224950695979" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="465.1469940835175" y1="-0.0" x2="465.1469940835175" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>
//           </g>
//         </g>
//         <g transform="translate(77.52449901391958 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             5
//             </text>
//           </g>
//         </g>
//         <g transform="translate(155.04899802783916 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             10
//             </text>
//           </g>
//         </g>
//         <g transform="translate(232.57349704175874 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             15
//             </text>
//           </g>
//         </g>
//         <g transform="translate(310.0979960556783 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             20
//             </text>
//           </g>
//         </g>
//         <g transform="translate(387.6224950695979 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             25
//             </text>
//           </g>
//         </g>
//         <g transform="translate(465.1469940835175 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             30
//             </text>
//           </g>
//         </g>
//         <line x1="0.0" y1="0.0" x2="537.2447781664627" y2="0.0" stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0">
//         </line>

// %%
createFrequencyTable("FaaS")
// Out:
// Line_166.jupyter.kts (1:1 - 21) Unresolved reference: createFrequencyTable

// %% [markdown]
// # Sistema operativo para desarrollo
//
// Windows sigue siendo el sistema operativo preferido para programar, aunque Mac OS y Linux le dan buena pelea ya.

// %%
createBarPlot("OS_dev", "Sistema operativo para desarrollo")
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="EB8bQI"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Sistema operativo para desarrollo"
// },
// "mapping":{
// },
// "data":{
// "Ocurrencias":[1.0,30.0,56.0,58.0],
// "OS_dev":["BSD","MacOS","Linux","Windows"]
// },
// "ggsize":{
// "width":950.0,
// "height":900.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "discrete":true
// },{
// "aesthetic":"x",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "y":"OS_dev",
// "x":"Ocurrencias",
// "fill":"OS_dev"
// },
// "stat":"identity",
// "orientation":"y",
// "sampling":"none",
// "position":"identity",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("EB8bQI");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=5f5f233f-3a66-4e2a-8f3b-2049065d7ed0 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="900.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pETVu6t .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pETVu6t .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pETVu6t .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pETVu6t .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pETVu6t .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pETVu6t .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pETVu6t .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dTe2Ubr .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pETVu6t .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pETVu6t .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dTe2Ubr .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pETVu6t .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pETVu6t .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dTe2Ubr .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dTe2Ubr .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dTe2Ubr .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pETVu6t">
//     <rect x="0.0" y="0.0" height="900.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(68.19636242915516 820.0 ) ">
//         <line x1="60.7238893607517" y1="-0.0" x2="60.7238893607517" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="121.4477787215034" y1="-0.0" x2="121.4477787215034" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="182.17166808225508" y1="-0.0" x2="182.17166808225508" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="242.8955574430068" y1="-0.0" x2="242.8955574430068" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="303.6194468037585" y1="-0.0" x2="303.6194468037585" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="364.34333616451016" y1="-0.0" x2="364.34333616451016" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="425.06722552526185" y1="-0.0" x2="425.06722552526185" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="485.7911148860136" y1="-0.0" x2="485.7911148860136" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="546.5150042467652" y1="-0.0" x2="546.5150042467652" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="607.238893607517" y1="-0.0" x2="607.238893607517" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="667.9627829682687" y1="-0.0" x2="667.9627829682687" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="728.6866723290203" y1="-0.0" x2="728.6866723290203" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>
//           </g>
//         </g>
//         <g transform="translate(60.7238893607517 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             5
//             </text>
//           </g>
//         </g>
//         <g transform="translate(121.4477787215034 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             10
//             </text>
//           </g>
//         </g>
//         <g transform="translate(182.17166808225508 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             15
//             </text>
//           </g>
//         </g>
//         <g transform="translate(242.8955574430068 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-a

// %%
createFrequencyTable("OS_dev")
// Out:
// Line_168.jupyter.kts (1:1 - 21) Unresolved reference: createFrequencyTable

// %% [markdown]
// # Sistema operativo en producción
//
// Aca no hay mucho por discutir, Linux ganó este terreno hace tiempo.

// %%
createBarPlot("OS_Prod", "Sistema operativo para producción")
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="BLFF6c"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Sistema operativo para producción"
// },
// "mapping":{
// },
// "data":{
// "Ocurrencias":[1.0,2.0,15.0,76.0],
// "OS_Prod":["BSD","MacOS","Windows","Linux"]
// },
// "ggsize":{
// "width":950.0,
// "height":900.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "discrete":true
// },{
// "aesthetic":"x",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "y":"OS_Prod",
// "x":"Ocurrencias",
// "fill":"OS_Prod"
// },
// "stat":"identity",
// "orientation":"y",
// "sampling":"none",
// "position":"identity",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("BLFF6c");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=fdb51fac-314a-4c9b-b20e-91da676dbdb0 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="900.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pEeRDBO .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEeRDBO .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEeRDBO .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEeRDBO .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEeRDBO .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEeRDBO .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEeRDBO .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dWhmx2J .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEeRDBO .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEeRDBO .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dWhmx2J .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEeRDBO .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEeRDBO .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dWhmx2J .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dWhmx2J .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dWhmx2J .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pEeRDBO">
//     <rect x="0.0" y="0.0" height="900.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(68.19636242915516 820.0 ) ">
//         <line x1="92.68383112956839" y1="-0.0" x2="92.68383112956839" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="185.36766225913678" y1="-0.0" x2="185.36766225913678" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="278.0514933887052" y1="-0.0" x2="278.0514933887052" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="370.73532451827356" y1="-0.0" x2="370.73532451827356" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="463.41915564784193" y1="-0.0" x2="463.41915564784193" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="556.1029867774104" y1="-0.0" x2="556.1029867774104" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="648.7868179069787" y1="-0.0" x2="648.7868179069787" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>
//           </g>
//         </g>
//         <g transform="translate(92.68383112956839 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             10
//             </text>
//           </g>
//         </g>
//         <g transform="translate(185.36766225913678 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             20
//             </text>
//           </g>
//         </g>
//         <g transform="translate(278.0514933887052 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             30
//             </text>
//           </g>
//         </g>
//         <g transform="translate(370.73532451827356 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             40
//             </text>
//           </g>
//         </g>
//         <g transform="translate(463.41915564784193 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             50
//             </text>
//           </g>
//         </g>
//         <g transform="translate(556.1029867774104 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             60
//             </text>
//           </g>
//         </g>
//         <g tr

// %%
createFrequencyTable("OS_Prod")
// Out:
// Line_170.jupyter.kts (1:1 - 21) Unresolved reference: createFrequencyTable

// %% [markdown]
// # Rol
//
// La mayoria de participantes se autopercibe como desarrollador de software aunque también varios arquitectos de software formaron parte de esta encuesta.

// %%
createFrequencyTable("Rol")
// Out:
// Line_171.jupyter.kts (1:1 - 21) Unresolved reference: createFrequencyTable

// %%
val column = "Rol"

val data = jvmData
        .filter { Rol != null }
        .split{ Rol }
        .by { it.split(",").map { it.trim() } }
        .intoRows()
        .groupBy{Rol}
        .aggregate { 
            count() into "Ocurrencias"
         }

data.plot{
         pie{
             slice(data.getColumn(1))
             fillColor("Rol") { 
                    scale = categoricalColorHue()
        
                }
             size = 50.0
         }
         layout.title = "Rol de los participantes"
            layout.size = 950 to 900
     }
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="KLAUtk"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Rol de los participantes"
// },
// "mapping":{
// },
// "data":{
// "Ocurrencias":[62.0,16.0,3.0,1.0,3.0,1.0,1.0,1.0],
// "Rol":["Desarrollador de software","Arquitecto de software","CIO/CTO/VP/Director","Consultor de Software","QA/Automation QA","Todologo","Project Manager","DBA"]
// },
// "ggsize":{
// "width":950.0,
// "height":900.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_hue"
// }],
// "layers":[{
// "mapping":{
// "slice":"Ocurrencias",
// "fill":"Rol"
// },
// "stat":"identity",
// "size":50.0,
// "sampling":"none",
// "position":"identity",
// "geom":"pie",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("KLAUtk");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=8ef73168-1e61-43f3-960d-60f4211b4dc3 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="900.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #puALnr2 .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #puALnr2 .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #puALnr2 .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #puALnr2 .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #puALnr2 .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #puALnr2 .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #puALnr2 .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dhZ4Tsr .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #puALnr2 .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #puALnr2 .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dhZ4Tsr .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #puALnr2 .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #puALnr2 .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dhZ4Tsr .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dhZ4Tsr .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dhZ4Tsr .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="puALnr2">
//     <rect x="0.0" y="0.0" height="900.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(42.99591213121782 820.0 ) ">
//         <line x1="64.98000521720331" y1="-0.0" x2="64.98000521720331" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="129.96001043440666" y1="-0.0" x2="129.96001043440666" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="194.94001565161" y1="-0.0" x2="194.94001565161" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="259.9200208688133" y1="-0.0" x2="259.9200208688133" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="324.9000260860167" y1="-0.0" x2="324.9000260860167" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="389.88003130322" y1="-0.0" x2="389.88003130322" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="454.86003652042336" y1="-0.0" x2="454.86003652042336" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="519.8400417376267" y1="-0.0" x2="519.8400417376267" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="584.8200469548301" y1="-0.0" x2="584.8200469548301" y2="-820.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             -0.5
//             </text>
//           </g>
//         </g>
//         <g transform="translate(64.98000521720331 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             -0.4
//             </text>
//           </g>
//         </g>
//         <g transform="translate(129.96001043440666 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             -0.3
//             </text>
//           </g>
//         </g>
//         <g transform="translate(194.94001565161 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             -0.2
//             </text>
//           </g>
//         </g>
//         <g transform="translate(259.9200208688133 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             -0.1
//             </text>
//           </g>
//         </g>
//         <g transform="translate(324.9000260860167 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0.0
//             </text>
//           </g>
//         </g>
//         <g transf

// %% [markdown]
// # Comentarios
//
// En general la gente está contenta con JConf pero muchos no pudieron asistir.

// %%
jvmData
        .filter { it.get("Jconf") != null }
        .get("Jconf")
        .forEach { println("- $it") }
// Out:
// - Si, para conocer personas y nuevas tendencias, todo bien, solo faltaron algunos stickers xD
// - Si asistí a la última que se realizó en agosto y me pareció una experiencia muy agradable en la cual aprendí bastante y me sentí motivado a pertenecer a esta comunidad.
// - Si, todo muy bien
// - Si, es una buena oportunidad para acercarse a gente del entorno
// - No
// - No, no pude por tiempo, que sea de varios dias
// - Sí, muchos temas interesantes, capacidad de hacer networking
// - no
// - No, por fechas y ubicación
// - Si pudieran hacerla en algún momento en Antigua Guatemala sería increíble
// - Se me pasó la fecha
// - No, fue en sábado.
// - Sí, para conocer a la comunidad y la gente que tambien gusta de Java. Tener mas playeras, o al menos tener playeras, sudaderos, etc. a la venta :D
// - No
// - Si, es un medio por el cual nos dan tips de desarrollo, herramientas y sobre todo de experiencias de personas expertas sobre como asumir cada situación
// - No asistí
// - -
// - Se actualiza
// - Si asistí. Sería cool implementar un tipo de hackathon que caída fin de semana, para poder desarrollar algo en base a las charlas.
// - Lamentablemente no pude asistir
// - Streaming de las conferencias.
// - No. Falta de tiempo
// - No, otra reunión
// - No asistí, me quedo lejos :(
// - No, nunca he podido
// - No pude asistir, posiblemente el próximo año!
// - No, no me enteré a tiempo
// - Mi comentario sería verificar las fechas del evento  para que las facultades no tengan atrasos con el tema de parciales y sea un día el cual puedan asistir.
// - No, me lo perdí :(
// - No tuve la oportunidad
// - Si, porque es una forma de conocer más personas y vender playeras o suaderos del evento
// - Si he asistido
// - Si muy alegre que regresen
// - Aún no
// - No pude asistir
// - Después de tanto tiempo por supuesto que quería, pero lamentablemente ya no pude llegar. A la próxima nos vemos por ahí!
// - No. Porque me enteré con muy poco tiempo de antelación, como que no hubo mucha difusión al respecto (en Twitter no vi nada de nada).
// - No pude asistir
// - No, quería pero estaba ocupada
// - Si, me pareció genial conocer gente aficionada a java. Estuvo genial
// - No pude asistir por lo largo del viaje a la capital, sin embargo si me gustaría hacerlo, me parece perfecto el evento, van por muy buen camino por como se están desarrollando
// - No, por la ubicación alguna actividad en Quetzaltenango
// - No, no tenía disponibilidad para asistir
// - No, tenía otros planes y ya no tuve tiempo de llegar
// - No
// - No he tenido el gusto, por mala planificación propia.
// - No. Falta de tiempo
// - No
// - Si en 2023, para conecte más el mundo Java y conocer la comunidad.
// - No asisti
// - No, porque me enteré muy tarde del evento y ya había pasado las fechas en que se realizaron, talves más publicidad para poder llegar a más personas
// - No
